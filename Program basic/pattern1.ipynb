# %%
num=5
for num in range(1,num+1):
 print("*")
# Out:
# *
# *
# *
# *
# *

# %%
num=5
for num in range(1,num+1):
 print( "*" ,end =" ")
# Out:
# * * * * *

# %%
row=5
col=5

for row in range(1,row+1):
      for col in range(1,col+1):
            print( "*",end = " ")            
      print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
row=5
col=5

for row in range(1,row+1):
      for col in range(1,row+1):
            print( "*",end = " ")            
            
      print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n=5
row=5
col=5
col1=5



for row in range(1 ,n+1 ):
     for col in range(1,n-row+1):
          print(" " ,end = " ")
     for col1 in range(1,row+1 ):
          print("*" , end = " ")
     print()
# Out:
#         *
#       * *
#     * * *
#   * * * *
# * * * * *

# %%
n=5
row=5
col=5
col1=5



for row in range(1 ,n+1 ):
     for col1 in range(1,row ):
          print(" " ,end = " ")
     for col in range(1,n-row+2):
          print("*" ,end = " ")
     
     print()
# Out:
# * * * * *
#   * * * *
#     * * *
#       * *
#         *

# %%
row=5
star=5
space=5
num=5

for row in range(1 , row+1):
      for star in range(1,num-row+2):
            print("*", end = " ")
      for space in range(1, row):
            print(" ", end = " ")
      print( )
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
row=5
num=5

for row in range (1,row+1):
      for space in range(1,num-row+1):
            print(" ",end=" ")
      for star in range(1,2*row):
            print("*",end=" ")
      print(" ")
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
row=5
num=5
for row in range(1, row+1):
      for space in range (1,row):
            print(" ", end=" ")
      for star in range(1,2*(num-row+1)):
            print("*", end=" ")
      print()
# Out:
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *

# %%
num=5

for row in range (1 ,num+1):
      for col in range(1,row+1):
            print("*",end=" ")
            
      print()

for row in range (1 ,num):
      for col in range(1,num-row+1):
            print("*",end=" ")

      print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
num=int(input("Enter num"))

print(" * "*num,end=" ")
# Out:
#  *  *  *  *  *  *  *  *  *  *

# %%
num=int(input("Enter num"))

for row in range (1,num+1):
      print(" * " * num)
# Out:
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *

# %%
num=int(input("Enter number"))

for row in range (1, num+1):
      col=row
      print(" * " * col)
# Out:
#  *
#  *  *
#  *  *  *
#  *  *  *  *
#  *  *  *  *  *

# %%
num=int(input("Enter number"))

for row in range (1, num+1):
      space=num-1
      star=num-row+1
      
      print("   " * space + " * " * star)

for row in range (1,num+1):
      print(" * " * num)
# Out:
#              *  *  *  *  *
#              *  *  *  *
#              *  *  *
#              *  *
#              *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *

# %%
num=int(input("Enter the Number"))

for row in range (1, num+1):
      space=num-3
      star=num-row+1
      
      print("   " * space + " * " * star)
for row in range (1, 3):
      space=num-3
      
      print("   " * space + " * " * star)

for row in range (1,num+1):
      print(" * " * num)
# Out:
#        *  *  *  *  *
#        *  *  *  *
#        *  *  *
#        *  *
#        *
#        *
#        *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *
#  *  *  *  *  *

# %%
num=int(input("Enter the Number"))

for row in range(1,num+1):
      space=num-row
      star =(2 * row)-1
      print("   " * space + " * " * star)
for row in range(1,num):
      space=row
      star=2*(num-row)-1
      print("   " * space + " * " * star)
# Out:
#              *
#           *  *  *
#        *  *  *  *  *
#     *  *  *  *  *  *  *
#  *  *  *  *  *  *  *  *  *
#     *  *  *  *  *  *  *
#        *  *  *  *  *
#           *  *  *
#              *

# %%
num=int(input("Enter the Number"))

for row in range(1,num+1):
      space=num-row
      star =(2 * row)-1
      print("   " * space + "*" * star)
for row in range(1,num):
      space=row
      star=2*(num-row)-1
      print("   " * space + "*" * star)
# Out:
#             *
#          ***
#       *****
#    *******
# *********
#    *******
#       *****
#          ***
#             *
