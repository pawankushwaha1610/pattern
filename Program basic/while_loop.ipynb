# %%
num=int(input("Inter the number"))
        
row=1
while(row<=num):
      print("*")
      row+=1
# Out:
# *
# *
# *
# *
# *

# %%
num=int(input("Enter the number"))
        
col=1
while(col<=num):
      print("*",end=" ")
      col+=1
# Out:
# * * * * *

# %%
num=int(input("Enter the number"))
        
row=1
while(row<=num):
      col=1
      while(col<=num):
            print("*",end=" ")
            col+=1
      print()
      row=row+1
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
num=int(input("Enter the number"))
        
row=1
while(row<=num):
      col=1
      while(col<=row):
            print("*",end=" ")
            col+=1
      print()
      row=row+1

# %%
num=int(input("Enter the number"))
        
row=1
while(row<=num):
      space=1
      while(space<=num-row):
            print(" ",end=" ")
            space+=1
      col=1
      while(col<=row):
            print("*",end=" ")
            col+=1
      print()
      row=row+1

# %%
num=int(input("E nter the number"))
        
row=1
while(row<=num):
      col=1
      while(col<=num-row+1):
            print("*",end=" ")
            col+=1
      print()
      row=row+1
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
num=int(input("Enter the number"))
        
row=1
while(row<=num):
      space=1
      while(space<=row):
            print(" ",end=" ")
            space=space+1
      col=1
      while(col<=num-row+1):
            print("*",end=" ")
            col+=1
      print()
      row=row+1
# Out:
#   * * * * *
#     * * * *
#       * * *
#         * *
#           *

# %%
num=int(input("Enter the number"))

row=1
while(row<=num):
      col=1
      while(col<=row):
            print("*",end=" ")
            col=col+1
      
      print()
      row=row+1

row=1
while(row<=num-1):
      col=1
      while(col<=num-row):
            print("*",end=" ")
            col=col+1
      
      print()
      row=row+1
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
num=int(input("Enter the Number"))

row=1
while(row<=num):
      space=1
      while(space<=num-row):
            print(" ",end=" ")
            space+=1
      col=1
      while(col<=row):
            print(" * ",end=" ")
            col+=1
      print()
      row+=1
# Out:
#          *
#        *   *
#      *   *   *
#    *   *   *   *
#  *   *   *   *   *

# %%
num=int(input("Enter the Number"))

row=1
while(row<=num):
      space=1
      while(space<=row-1):
            print(" ",end=" ")
            space+=1
      col=1
      while(col<=num-row+1):
            print(" * ",end=" ")
            col+=1
      print()
      row+=1
# Out:
#  *   *   *   *   *
#    *   *   *   *
#      *   *   *
#        *   *
#          *

# %%
num=int(input("Enter the Number"))

row=1
while(row<=num):
      space=1
      while(space<=num-row):
            print(" ",end=" ")
            space+=1
      col=1
      while(col<=row):
            print(" * ",end=" ")
            col+=1
      print()
      row+=1
row=1
while(row<=num-1):
      space=1
      while(space<=row):
            print(" ",end=" ")
            space+=1
      col=1
      while(col<=num-row):
            print(" * ",end=" ")
            col+=1
      print()
      row+=1
# Out:
#          *
#        *   *
#      *   *   *
#    *   *   *   *
#  *   *   *   *   *
#    *   *   *   *
#      *   *   *
#        *   *
#          *

# %%
num=int(input(" Enter the Number"))

while(num>0):
      num1=num%10
      print(num1,end=" ")
      num=num//10
# Out:
# 2 1 4 7

# %%
#write the program to calculate the sum of the digit.

num=int(input(" Enter the Number"))
sum=0
while(num>0):
      num1=num%10
      sum=sum+num1
      num=num//10
print(sum)
# Out:
# 10

# %%
#write the program to calculate the Revers no. of the digit.

num=int(input("Enter the Number"))
rev=0
while(num>0):
      digit=num % 10
      rev=rev*10+digit
      num=num//10

print(rev)
# Out:
# 4321

# %%
#write the program to check Enter digit is Armstrong  or not.


num=int(input("Enter the Number"))
num1=num
arm=0
while(num>0):
      digit=num % 10
      digit1=digit**3
      arm=arm+digit1
      num=num//10
print(arm)

if(num1==arm):
      print("This is Arm strong number ")
else:
      print("This is not Arm strong number ")
# Out:
# 36
# This is not Arm strong number

# %%
#write the program to check Enter digit is Pallendrom  number or not .

num=int(input("Enter the Number"))
num1=num

rev=0
while(num>0):
      digit=num%10
      rev=rev *10 + digit
      num=num//10
print(rev)

if(num1==rev):
      print("This is pallendrom Number")
else:
     print("This is not  pallendrom Number")
# Out:
# 323
# This is pallendrom Number
